# %%
#Import data preprocessing modules
import numpy as np
import numpy.random as random
import scipy as sp
from pandas import Series, DataFrame
import pandas as pd

# Visualization modules
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline

# Machine learning module
import sklearn

# %%
#Read the file
#Write the code
dataset = pd.read_csv('input/titanic.csv')

#Show the first 50 rows
#Write the code
dataset.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
#Observe the data shape
#Write the code
dataset.shape
# Out:
# (891, 12)

# %%
#Observe the data information
#Write the code
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Set seaborn as the default drawing library
#Write the code
sns.set()

# %%
def bar_chart(feature):
    #Write the code
    survived = dataset[dataset['Survived']==1][feature].value_counts()
    dead = dataset[dataset['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
#Bar Chat of Survival/Dead Men and Women
#Write the code
bar_chart('Sex')

# %%
#Bar Chat of the Cabin of the Survival/Dead Person
#Write the code
bar_chart('Pclass')

# %%
#Calculate the number of “NaN” in the columns 
#Write the code
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Name

# %%
#Observe the Name column
#Write the code
dataset['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#Pick out Mr., Mrs., Miss
dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
#https://reurl.cc/qeZQE
#https://reurl.cc/Neb8n

# %%
#Count the Number of People by Each Title
#Write the code
dataset['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: Title, dtype: int64

# %%
#titlemapping
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, "Master": 3, "Dr": 3, 
                 "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, 
                 "Mme": 3,"Capt": 3,"Sir": 3 }
dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
#Current dataset
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      2
# ...

# %%
#Current dataframe
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      2
# ...

# %%
#Show the Distribution of Title/Survival and Dead
#Write the code
bar_chart("Title")

# %%
#Delete the "Name" column
#Write the code
dataset.drop("Name", inplace=True, axis=1)

# %%
#Current dataframe
dataset.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  Title
# 0         A/5 21171   7.2500   NaN        S      0
# 1          PC 17599  71.2833   C85        C      2
# 2  STON/O2. 3101282   7.9250   NaN        S      1
# 3            113803  53.1000  C123        S      2
# 4            373450   8.0500   NaN        S      0

# %% [markdown]
# # Sex

# %%
#mapping sex
#Write the code
sex_mapping = {"male":0, "female": 1}
dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
bar_chart('Sex')

# %%
#Current dataframe
dataset.head(100)
# Out:
#     PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  22.0      1      0         A/5 21171
# 1             2         1       1    1  38.0      1      0          PC 17599
# 2             3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  35.0      1      0            113803
# 4             5         0       3    0  35.0      0      0            373450
# ..          ...       ...     ...  ...   ...    ...    ...               ...
# 95           96         0       3    0   NaN      0      0            374910
# 96           97         0       1    0  71.0      0      0          PC 17754
# 97           98         1       1    0  23.0      0      1          PC 17759
# 98           99         1       2    1  34.0      0      1            231919
# 99          100         0       2    0  34.0      1      0            244367
#
#        Fare    Cabin Embarked  Title
# ...

# %% [markdown]
# # Age

# %%
# fill missing age with median age for each title (Mr, Mrs, Miss, Others)
#Write the code
dataset["Age"].fillna(dataset.groupby("Title")["Age"].transform("median"), inplace = True)
dataset["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    21.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#Distribution of Age/Survival and Death
facet = sns.FacetGrid(dataset, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Age',shade= True)
facet.set(xlim=(0, dataset['Age'].max()))
facet.add_legend()
 
plt.show()

# %%
#Mapping Function According to the Range of Age 
#Write the code
dataset.loc[dataset["Age"]<=16, "Age"]=0
dataset.loc[(dataset["Age"]> 16)&(dataset["Age"]<= 26), "Age"]=1
dataset.loc[(dataset["Age"]> 26)&(dataset["Age"]<= 36), "Age"]=2
dataset.loc[(dataset["Age"]> 36)&(dataset["Age"]<= 62), "Age"]=3
dataset.loc[dataset["Age"] > 62, "Age"]=4

# %%
#Current dataframe
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
#Bar Chart of Age
#Write the code
bar_chart("Age")

# %% [markdown]
# # Embarked (登船地點)

# %%
#Analyze the Type of Boarding Tickets at Each Boarding Location
#Write the code
Pclass1 = dataset[dataset["Pclass"]==1]["Embarked"].value_counts()
Pclass2 = dataset[dataset["Pclass"]==2]["Embarked"].value_counts()
Pclass3 = dataset[dataset["Pclass"]==3]["Embarked"].value_counts()
df=pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
#Fill Missing Value for Embarked Location
#Write the code
dataset["Embarked"] = dataset["Embarked"].fillna("S")
dataset.head(100)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  1.0      1      0         A/5 21171
# 1             2         1       1    1  3.0      1      0          PC 17599
# 2             3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  2.0      1      0            113803
# 4             5         0       3    0  2.0      0      0            373450
# ..          ...       ...     ...  ...  ...    ...    ...               ...
# 95           96         0       3    0  2.0      0      0            374910
# 96           97         0       1    0  4.0      0      0          PC 17754
# 97           98         1       1    0  1.0      0      1          PC 17759
# 98           99         1       2    1  2.0      0      1            231919
# 99          100         0       2    0  2.0      1      0            244367
#
#        Fare    Cabin Embarked  Title
# ...

# %%
#Mapping Function for the Embarked Location
#Write the code
embarked_mapping = {"S":0, "C": 1, "Q": 2}
dataset['Embarked'] = dataset['Embarked'].map(embarked_mapping)
dataset.head(100)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  1.0      1      0         A/5 21171
# 1             2         1       1    1  3.0      1      0          PC 17599
# 2             3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  2.0      1      0            113803
# 4             5         0       3    0  2.0      0      0            373450
# ..          ...       ...     ...  ...  ...    ...    ...               ...
# 95           96         0       3    0  2.0      0      0            374910
# 96           97         0       1    0  4.0      0      0          PC 17754
# 97           98         1       1    0  1.0      0      1          PC 17759
# 98           99         1       2    1  2.0      0      1            231919
# 99          100         0       2    0  2.0      1      0            244367
#
#        Fare    Cabin  Embarked  Title
# ...

# %% [markdown]
# # Fare(票價)

# %%
#Fill in Missing Value for Fares 
#Write the code
dataset["Fare"].fillna(dataset.groupby("Pclass")["Fare"].transform("median"), inplace = True)
dataset.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  1.0      1      0         A/5 21171
# 1             2         1       1    1  3.0      1      0          PC 17599
# 2             3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  2.0      1      0            113803
# 4             5         0       3    0  2.0      0      0            373450
# 5             6         0       3    0  2.0      0      0            330877
# 6             7         0       1    0  3.0      0      0             17463
# 7             8         0       3    0  0.0      3      1            349909
# 8             9         1       3    1  2.0      0      2            347742
# 9            10         1       2    1  0.0      1      0            237736
# 10           11         1       3    1  0.0      1      1           PP 9549
# ...

# %%
#Distribution of Fare/Survival and Death
facet = sns.FacetGrid(dataset, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'Fare',shade= True)
facet.set(xlim=(0, dataset['Fare'].max()))
facet.add_legend()
 
plt.show()

# %%
#Mapping Function According to the Range of Fare
#Write the code
dataset.loc[dataset["Fare"]<=17, "Fare"]=0
dataset.loc[(dataset["Fare"]> 17)&(dataset["Fare"]<= 30), "Fare"]=1
dataset.loc[(dataset["Fare"]> 30)&(dataset["Fare"]<= 100), "Fare"]=2
dataset.loc[dataset["Fare"] > 100, "Fare"]=3

# %%
#Current dataframe
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare Cabin  Embarked  Title
# 0   0.0   NaN         0      0
# 1   2.0   C85         1      2
# 2   0.0   NaN         0      1
# 3   2.0  C123         0      2
# 4   0.0   NaN         0      0

# %%
#Observe the Cabin Number
#Write the code
dataset["Cabin"].value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
#Observe the Cabin Number =>Take out the first letter
#Write the code
dataset["Cabin"] = dataset["Cabin"].str[:1]
dataset["Cabin"]
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: Cabin, Length: 891, dtype: object

# %%
#Analyze the Number of People in Various Ticket Types and Cabin Types
#Write the code
Pclass1 = dataset[dataset["Pclass"]==1]["Cabin"].value_counts()
Pclass2 = dataset[dataset["Pclass"]==2]["Cabin"].value_counts()
Pclass3 = dataset[dataset["Pclass"]==3]["Cabin"].value_counts()
df=pd.DataFrame([Pclass1, Pclass2, Pclass3])
df.index = ['1st class','2nd class', '3rd class']
df.plot(kind='bar',stacked=True, figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
#Cabin Mapping
#Write the code
cabin_mapping = {"A":0, "B": 0.4, "C": 0.8, "D": 1.2, 
                 "E":1.6,"F":2,"G":2.4,"T":2.8}
dataset['Cabin'] = dataset['Cabin'].map(cabin_mapping)

# %%
#Fill in the Missing Value on the Type of Cabin
#Write the code
dataset['Cabin'].fillna(dataset.groupby('Pclass')['Cabin'].transform('median'), inplace=True)

# %%
#Current dataframe
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare  Cabin  Embarked  Title
# 0   0.0    2.0         0      0
# 1   2.0    0.8         1      2
# 2   0.0    2.0         0      1
# 3   2.0    0.8         0      2
# 4   0.0    2.0         0      0

# %% [markdown]
# # Sibsp & Parch

# %%
#Combine Sibsp & Parch
#Write the code
dataset["FamilySize"] = dataset["SibSp"] + dataset["Parch"]+1

# %%
#Distribution of Family Population/Survival and Death
facet = sns.FacetGrid(dataset, hue="Survived",aspect=4)
facet.map(sns.kdeplot,'FamilySize',shade= True)
facet.set(xlim=(0, dataset['FamilySize'].max()))
facet.add_legend()
plt.xlim(0)
# Out:
# (0.0, 11.0)

# %%
#The Mapping Function of Family Population 
#Write the code
family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 
                  8: 2.8, 9: 3.2, 10: 3.6, 11: 4}
dataset['FamilySize'] = dataset['FamilySize'].map(family_mapping)

# %%
#Current dataframe
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  1.0      1      0         A/5 21171
# 1            2         1       1    1  3.0      1      0          PC 17599
# 2            3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  2.0      1      0            113803
# 4            5         0       3    0  2.0      0      0            373450
#
#    Fare  Cabin  Embarked  Title  FamilySize
# 0   0.0    2.0         0      0         0.4
# 1   2.0    0.8         1      2         0.4
# 2   0.0    2.0         0      1         0.0
# 3   2.0    0.8         0      2         0.4
# 4   0.0    2.0         0      0         0.0

# %% [markdown]
# # Data Cleaning (資料清洗)

# %%
#Delete Sibsp, Parch, Ticket
#Write the code
features_drop = ["Ticket", "SibSp", "Parch", "PassengerId"]
dataset=dataset.drop(features_drop, axis=1)

# %%
#Set Target Variables and Explanatory Variables
#Write the code
dataset_data = dataset.drop("Survived", axis = 1)
dataset_target = dataset["Survived"]
dataset_data.shape, dataset_target.shape
# Out:
# ((891, 8), (891,))

# %%
#survived(dataset_target)為series,加入中括號轉乘dataframe
dataset_target2 = dataset[['Survived']]
dataset_data.shape, dataset_target2.shape
# Out:
# ((891, 8), (891, 1))

# %%
#All explanatory variables
dataset_data.head()
# Out:
#    Pclass  Sex  Age  Fare  Cabin  Embarked  Title  FamilySize
# 0       3    0  1.0   0.0    2.0         0      0         0.4
# 1       1    1  3.0   2.0    0.8         1      2         0.4
# 2       3    1  1.0   0.0    2.0         0      1         0.0
# 3       1    1  2.0   2.0    0.8         0      2         0.4
# 4       3    0  2.0   0.0    2.0         0      0         0.0

# %%
#Check the types of every column in the training data.
#They should be numeric type.
#Write the code
dataset_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Pclass      891 non-null    int64
#  1   Sex         891 non-null    int64
#  2   Age         891 non-null    float64
#  3   Fare        891 non-null    float64
#  4   Cabin       891 non-null    float64
#  5   Embarked    891 non-null    int64
#  6   Title       891 non-null    int64
#  7   FamilySize  891 non-null    float64
# dtypes: float64(4), int64(4)
# memory usage: 55.8 KB

# %% [markdown]
# # Build the model-DNN

# %%
#Install Keras and Sklearn
#Write the code
from keras.models import Sequential
from keras.layers.core import Dense,Activation
from keras.optimizers import Adam
from sklearn import preprocessing

# %%
#Create Model Function
def build_model():
#Write the code
    #contruct model
    model = Sequential()
    #stack model
    model.add(Dense(input_dim=8,units=40)) #The number of columns for each data
    model.add(Activation("relu"))
    model.add(Dense(units=100))
    model.add(Activation("relu"))
    model.add(Dense(units=10))
    model.add(Activation("relu"))
    model.add(Dense(units=1))
    model.add(Activation("sigmoid"))
    model.summary()
    return model

# %%
#Create a Drawing Function
def show_train_history(train_history,train,validation,label):
    #Write the code
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title("Train History")
    plt.ylabel(label)
    plt.xlabel("Epoch")
    plt.legend(['train','validation'],loc='upper left')
    plt.show()

# %%
#Feature Normalization
#Write the code
minmax_scale = preprocessing.MinMaxScaler(feature_range=(0, 1))
scaledFeatures = minmax_scale.fit_transform(dataset_data)

# %%
model = build_model()
#Train Model
#Write the code
model.compile(loss='binary_crossentropy',optimizer="adam",metrics=['acc'])
train_history = model.fit(x=dataset_data,y=dataset_target2,
                          validation_split=0.2,batch_size=30,epochs=40)

#Evaluate training result
#Write the code
score = model.evaluate(x=scaledFeatures, y=dataset_target2)
print ('\nTrain Loss:', score[0])
print ('\nTrain Acc:', score[1])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 40)                360
#
#  activation (Activation)     (None, 40)                0
#
#  dense_1 (Dense)             (None, 100)               4100
#
#  activation_1 (Activation)   (None, 100)               0
#
#  dense_2 (Dense)             (None, 10)                1010
#
#  activation_2 (Activation)   (None, 10)                0
#
#  dense_3 (Dense)             (None, 1)                 11
#
#  activation_3 (Activation)   (None, 1)                 0
#
# ...
# Total params: 5,481
# Trainable params: 5,481
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
# 24/24 [==============================] - 1s 7ms/step - loss: 0.5998 - acc: 0.6573 - val_loss: 0.4929 - val_acc: 0.7821
# Epoch 2/40
# ...

# %%
#Show Training Process
#Write the code
show_train_history(train_history,'acc','val_acc','accuracy')
show_train_history(train_history,'loss','val_loss','loss')

# %% [markdown]
# # Test Model

# %%
def data_cleaning(testdata):
    testdata['Title'] = testdata['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
    title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, "Master": 3, "Dr": 3, 
                     "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                     "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, 
                     "Mme": 3,"Capt": 3,"Sir": 3 }
    testdata['Title'] = testdata['Title'].map(title_mapping)
    ###
    sex_mapping = {"male":0, "female": 1}
    testdata['Sex'] = testdata['Sex'].map(sex_mapping)
    ###
    testdata["Age"].fillna(testdata.groupby("Title")["Age"].transform("median"), inplace = True)
    testdata.loc[testdata["Age"]<=16, "Age"]=0
    testdata.loc[(testdata["Age"]> 16)&(testdata["Age"]<= 26), "Age"]=1
    testdata.loc[(testdata["Age"]> 26)&(testdata["Age"]<= 36), "Age"]=2
    testdata.loc[(testdata["Age"]> 36)&(testdata["Age"]<= 62), "Age"]=3
    testdata.loc[testdata["Age"] > 62, "Age"]=4
    ###
    testdata["Embarked"] = testdata["Embarked"].fillna("S")
    embarked_mapping = {"S":0, "C": 1, "Q": 2}
    testdata['Embarked'] = testdata['Embarked'].map(embarked_mapping)
    ###
    testdata["Fare"].fillna(testdata.groupby("Pclass")["Fare"].transform("median"), inplace = True)
    testdata.loc[testdata["Fare"]<=17, "Fare"]=0
    testdata.loc[(testdata["Fare"]> 17)&(testdata["Fare"]<= 30), "Fare"]=1
    testdata.loc[(testdata["Fare"]> 30)&(testdata["Fare"]<= 100), "Fare"]=2
    testdata.loc[testdata["Fare"] > 100, "Fare"]=3
    ###
    testdata["Cabin"] = testdata["Cabin"].str[:1]
    cabin_mapping = {"A":0, "B": 0.4, "C": 0.8, "D": 1.2, 
                 "E":1.6,"F":2,"G":2.4,"T":2.8}
    testdata['Cabin'] = testdata['Cabin'].map(cabin_mapping)
    testdata['Cabin'].fillna(testdata.groupby('Pclass')['Cabin'].transform('median'), inplace=True)
    ###
    testdata["FamilySize"] = testdata["SibSp"] + testdata["Parch"]+1
    family_mapping = {1: 0, 2: 0.4, 3: 0.8, 4: 1.2, 5: 1.6, 6: 2, 7: 2.4, 
                  8: 2.8, 9: 3.2, 10: 3.6, 11: 4}
    testdata['FamilySize'] = testdata['FamilySize'].map(family_mapping)
    ###
    features_drop = ["Name","Ticket", "SibSp", "Parch", "PassengerId"]
    testdata=testdata.drop(features_drop, axis=1)
    
    return testdata

# %%
#Preprocess the test data in the same way as the training data.
testdata = pd.read_csv('input/test.csv')
testdata = data_cleaning(testdata)

# %%
#USe model.predict to predict the probability of survival
#Write the code
probability = model.predict(testdata)
probability=probability.flatten()
testdata_write = pd.read_csv('input/test.csv')
submission = pd.DataFrame({
    "PassengerId": testdata_write['PassengerId'],
    "Survived" : probability
    })
submission.to_csv('submission.csv', index=False)

probability = probability.round(0).astype(int)

KaggleSubmission = pd.DataFrame({
    "PassengerId": testdata_write['PassengerId'],
    "Survived" : probability
    })
KaggleSubmission.to_csv('KaggleSubmissionDNN.csv', index=False)
# Out:
# 14/14 [==============================] - 0s 771us/step

# %%
jrdata = pd.read_csv('input/test-rosejack.csv')
jrdata = data_cleaning(jrdata)
jrprobability = model.predict(jrdata)
jrprobability
# Out:
# 1/1 [==============================] - 0s 14ms/step
# array([[0.13241597],
#        [0.9683393 ]], dtype=float32)

# %%
#Obtain the weights of the model
#Write the code
W, b=model.layers[0].get_weights()
print("weights = {},\n\n biases= {}".format(W, b))
# Out:
# weights = [[-2.38773733e-01 -2.69342452e-01  2.58418530e-01 -3.06380779e-01
#    3.47515553e-01 -2.92723591e-04 -9.47032869e-02  1.80924445e-01
#   -3.32418174e-01 -1.90707102e-01 -9.34761018e-03  2.04113007e-01
#    2.13130757e-01  1.04629070e-01  2.71702353e-02  3.18233430e-01
#   -4.94493917e-02 -1.88708290e-01 -2.63060868e-01 -1.89298883e-01
#    2.78462768e-02 -2.84400731e-01  2.21268479e-02  1.81716695e-01
#   -1.43838823e-01 -2.91142970e-01 -3.77299130e-01  2.84791678e-01
#   -8.89368169e-03  1.95619360e-01 -1.08519658e-01 -1.83465838e-01
#   -1.67441946e-02 -2.19455764e-01 -3.27325821e-01  7.88280666e-02
#    8.54251236e-02  7.67114908e-02  1.16877370e-02  3.19899619e-01]
#  [-4.40543085e-01 -3.99045140e-01  2.26630360e-01 -5.08095562e-01
#    1.30687049e-02 -2.81444103e-01  2.65606672e-01  3.19238186e-01
#   -1.92060575e-01 -3.10702324e-01 -3.09215207e-03 -1.48611933e-01
#   -1.08322427e-01 -6.25793412e-02 -3.49210799e-01  2.31934413e-01
# ...

# %%
#Save the model
#Write the code
model.save('dnnfortitanic.h5')

# %%
answer = pd.read_csv('ans.csv')
expectedans = answer.Survived.values

# %% [markdown]
# ### SVM

# %%
#svm
#Import library
# Write the code
from sklearn.model_selection import KFold
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn import ensemble, metrics
import math

#10-fold cross-validation
# Write the code
kfold = KFold(10,shuffle=True,random_state=None)
predictedsvm = []
expectedsvm = []

for train, test in kfold.split(dataset_data):
    X_train= dataset_data.iloc[train]
    Y_train = dataset_target2.iloc[train]
    X_test = dataset_data.iloc[test]
    Y_test = dataset_target2.iloc[test]
    svm = OneVsRestClassifier(SVC(gamma='scale')).fit(X_train, Y_train)
    predictedsvm.extend(svm.predict(X_test))
    expectedsvm.extend(Y_test)

# %%
svmpredicted = svm.predict(testdata)
svmpredicted=svmpredicted.flatten().round(0).astype(int)

KaggleSubmissionSVM = pd.DataFrame({
    "PassengerId": testdata_write['PassengerId'],
    "Survived" : svmpredicted
    })
KaggleSubmissionSVM.to_csv('KaggleSubmissionSVM.csv', index=False)

# %%
print(metrics.classification_report(expectedans,svmpredicted))
print(metrics.confusion_matrix(expectedans, svmpredicted))
accuracy = accuracy_score(expectedans, svmpredicted)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print('precision:',metrics.precision_score(expectedans, svmpredicted,average='macro')) 
print('recall:',metrics.recall_score(expectedans, svmpredicted,average='macro'))
print('F1-score:',metrics.f1_score(expectedans, svmpredicted,average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95       266
#            1       0.89      0.95      0.92       152
#
#     accuracy                           0.94       418
#    macro avg       0.93      0.94      0.93       418
# weighted avg       0.94      0.94      0.94       418
#
# [[248  18]
#  [  8 144]]
# Accuracy: 93.78%
# precision: 0.9288194444444444
# recall: 0.9398496240601504
# F1-score: 0.9336945115552626

# %% [markdown]
# ### Random Forest

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC


kfold = KFold(10,shuffle=True,random_state=None)
predictedfor = []
expectedfor = []
for train, test in kfold.split(dataset_data):
    X_train= dataset_data.iloc[train]
    Y_train = dataset_target2.iloc[train]
    X_test = dataset_data.iloc[test]
    Y_test = dataset_target2.iloc[test]
    forest = ensemble.RandomForestClassifier(n_estimators = 100)
    forest.fit(X_train,Y_train.values.ravel())
    predictedfor.extend(forest.predict(X_test))
    expectedfor.extend(Y_test)

# %%
forpredicted = forest.predict(testdata)
forpredicted=forpredicted.flatten().round(0).astype(int)


KaggleSubmissionFOR = pd.DataFrame({
    "PassengerId": testdata_write['PassengerId'],
    "Survived" : forpredicted
    })
KaggleSubmissionFOR.to_csv('KaggleSubmissionFOR.csv', index=False)

# %%
print(metrics.classification_report(expectedans,forpredicted))
print(metrics.confusion_matrix(expectedans, forpredicted))
accuracy = accuracy_score(expectedans, forpredicted)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print('precision:',metrics.precision_score(expectedans, forpredicted,average='macro')) 
print('recall:',metrics.recall_score(expectedans, forpredicted,average='macro'))
print('F1-score:',metrics.f1_score(expectedans, forpredicted,average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       266
#            1       0.80      0.81      0.81       152
#
#     accuracy                           0.86       418
#    macro avg       0.85      0.85      0.85       418
# weighted avg       0.86      0.86      0.86       418
#
# [[236  30]
#  [ 29 123]]
# Accuracy: 85.89%
# precision: 0.84724380318165
# recall: 0.8482142857142857
# F1-score: 0.8477231329690345

# %%
print(metrics.classification_report(expectedans,probability))
print(metrics.confusion_matrix(expectedans, probability))
accuracy = accuracy_score(expectedans, probability)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print('precision:',metrics.precision_score(expectedans, probability,average='macro')) 
print('recall:',metrics.recall_score(expectedans, probability,average='macro'))
print('F1-score:',metrics.f1_score(expectedans, probability,average='macro'))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.91       266
#            1       0.82      0.89      0.86       152
#
#     accuracy                           0.89       418
#    macro avg       0.88      0.89      0.88       418
# weighted avg       0.89      0.89      0.89       418
#
# [[236  30]
#  [ 16 136]]
# Accuracy: 89.00%
# precision: 0.8778925224708357
# recall: 0.8909774436090225
# F1-score: 0.8832714115732982
